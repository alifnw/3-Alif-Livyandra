# %%
HelloWorld("print")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-466/1240100671.py in <cell line: 0>()
# ----> 1 HelloWorld("print")
#
# NameError: name 'HelloWorld' is not defined
